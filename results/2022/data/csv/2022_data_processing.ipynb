# %% [markdown]
# # Simple Pre-Processing for the Raw results
# This notebook applies some basic preproccessing on the raw survey results, mainly:
# - Transforming the "JSON" files into "CSV" which is more friendly and common for data analysis tasks.
# - Decoding the questions and answers values to natural language categories, in order to use for future work.
#
# **Let's GO!**

# %% [markdown]
# ### Imports

# %%
import pandas as pd 
import json

# %% [markdown]
# ### Read the Json Files

# %%
with open('./../results.json') as f:
    data = json.load(f)
SOD_Morocco = pd.DataFrame(data['results'])
SOD_Morocco.head()
# Out:
#                          userId  community-q-7  community-q-3  \
# 0  034cxKbcScSkMKWBkhu9xC6ubRE2            2.0            4.0
# 1  04TsCbQGWxg9S2cudIT86e0CMH03            3.0            4.0
# 2  05THu8aCmBUOnxCCGXESKeqlcVQ2            3.0            0.0
# 3  06zWHRXkimdBlINCzJ3warn55V53            NaN            NaN
# 4  08A0JzKQixVjdjCE49QboELB1do1            NaN            NaN
#
#                    tech-q-8  profile-q-3  profile-q-7 community-q-1  \
# 0  [0, 1, 7, 9, 10, 12, 17]          4.0          1.0           [2]
# 1                    [1, 9]          1.0          0.0           [0]
# 2                      [19]         10.0          4.0           [0]
# 3                       NaN         13.0          4.0           NaN
# 4                       NaN          2.0          3.0           NaN
#
#    profile-q-2  profile-q-4      startTime  ... education-q-4  tech-q-11  \
# 0          3.0          1.0  1672917044607  ...           1.0        0.0
# 1          3.0          1.0  1671819917339  ...           1.0        1.0
# 2          1.0          1.0  1672216451960  ...           1.0        3.0
# 3          5.0          1.0  1671789215475  ...           1.0        NaN
# 4          2.0          2.0  1672386895995  ...           NaN        NaN
#
#    education-q-5                      tech-q-0  tech-q-5 profile-q-5  \
# 0            0.0        [0, 1, 3, 4, 5, 9, 10]      None         0.0
# 1            0.0  [0, 1, 2, 3, 4, 5, 6, 7, 10]   [7, 12]         0.0
# 2            2.0                           [1]      None         0.0
# 3            0.0                           NaN       NaN         1.0
# 4            NaN                           NaN       NaN         3.0
#
#   education-q-3 tech-q-16  work-q-6 profile-q-1
# 0  [0, 2, 3, 4]       2.0       NaN         1.0
# 1     [0, 2, 3]       0.0       7.0         2.0
# 2        [0, 3]       2.0       NaN         1.0
# 3     [0, 2, 3]       NaN       NaN         1.0
# 4           NaN       NaN       NaN         1.0
#
# [5 rows x 59 columns]

# %%
SOD_Morocco_qst = pd.read_json("./../questions.json")
SOD_Morocco_qst.head()
# Out:
#                    profile-q-0  \
# multiple                 False
# label     What is your gender?
# required                  True
# choices         [Male, Female]
#
#                                                 profile-q-1  \
# multiple                                               None
# label                                     What is your age?
# required                                               True
# choices   [Younger than 18 years, 18 to 24 years, 25 to ...
#
#                                                 profile-q-2  \
# multiple                                               None
# label                      Where are you currently located?
# required                                               True
# choices   [Rabat-Salé-Kénitra, Casablanca-Settat, Marrak...
#
#                                                 profile-q-3  \
# multiple                                               None
# label                              What is your occupation?
# required                                               True
# choices   [Back-end developer, Full-stack developer, Fro...
#
#                                                 profile-q-4  \
# multiple                                               None
# label                         What is your highest diploma?
# required                                               True
# choices   [Self-taught, Bac +2/+3, Bachelor’s degree (B....
#
#                                                 profile-q-5  \
# multiple                                               None
# label     How many years have you been coding profession...
# required                                               True
# choices   [I don't have any professional coding experien...
#
#                          profile-q-6  \
# multiple                        None
# label     Is coding a hobby for you?
# required                        True
# choices                    [Yes, No]
#
#                                                 profile-q-7  \
# multiple                                               None
# label        Do you have any plans to work outside Morocco?
# required                                               True
# choices   [Yes, in the next 12 months, Yes, in the next ...
#
#                                                 profile-q-8  \
# multiple                                               None
# label     If you are working abroad, do you have any pla...
# required                                                NaN
# choices                         [Yes, Still hesitating, No]
#
#                                                profile-q-9  ...  \
# multiple                                              None  ...
# label              What do you usually drink while coding?  ...
# required                                              True  ...
# choices   [Tea, Coffee, Water, Energy drinks, None, Other]  ...
#
#                                                   tech-q-15  \
# multiple                                               True
# label     The production database you or your team are u...
# required                                                NaN
# choices   [Oracle Database, Mysql/MariaDB, PostgreSQL, S...
#
#                                                   tech-q-16  \
# multiple                                               None
# label     How often do you use AI tools for Dev (Github ...
# required                                               True
# choices       [Daily, Tried them but not interested, Never]
#
#                                               community-q-0  \
# multiple                                              False
# label     How far are you involved in any local develope...
# required                                               True
# choices   [No, I am not interested, I know some, but not...
#
#                                               community-q-1  \
# multiple                                               True
# label     Did you ever participate in an open-source pro...
# required                                               True
# choices   [I don’t have an account on Github (or alterna...
#
#                                               community-q-2  \
# multiple                                               None
# label           Did you get the chance to write blog posts?
# required                                               True
# choices   [No, I am not interested., Still thinking abou...
#
#                                               community-q-3  \
# multiple                                              False
# label     When it comes to IT, what is your primary soci...
# required                                               True
# choices   [Facebook, Instagram, WhatsApp, Twitter, Youtu...
#
#                                               community-q-4  \
# multiple                                               None
# label     How many IT events did you attend in the last ...
# required                                               True
# choices                               [0, 1-3, More than 3]
#
#                                               community-q-5  \
# multiple                                               None
# label     How many talks did you participate in the last...
# required                                               True
# choices                       [0, 1 - 3 talks, More than 3]
#
#                                               community-q-6  \
# multiple                                               None
# label                                        Do you prefer?
# required                                               True
# choices   [Live/online events, In-person events?, Li ja ...
#
#                                              community-q-7
# multiple                                              None
# label     How do you evaluate the Moroccan Tech Community?
# required                                              True
# choices                    [Bad, Not Bad, Good, Excellent]
#
# [4 rows x 56 columns]

# %% [markdown]
# ### Translate the survey codes and abbreviations

# %%
SOD_qst_dict = {
    "profile-q-0":"Gender",
    "profile-q-1":"Age", 
    "profile-q-2":"Country",
    "profile-q-3":"Job_Title",
    "profile-q-4":"Education",
    "profile-q-5":"Coding_Experience",
    "profile-q-6":"Coding_as_Hobby",
    "profile-q-7":"Immigration_Plans",
    "profile-q-8":"Reentery_Plans",
    "profile-q-9":"Fav_Coding_Drink",
    "education-q-0":"Coding_Education",
    "education-q-1":"Teaching_Jobs_Gap",
    "education-q-2":"Teaching_Problems_POV",
    "education-q-3":"Read_Write_Languages",
    "education-q-4":"English_Barrier",
    "education-q-5":"Local_Dialect_Content",
    "education-q-6":"Learning_Platforms",
    "tech-q-0":"Fav_Programming_Languages",
    "tech-q-1":"Wanted_Programming_Languages",
    "tech-q-2":"Daily_Programming_Languages",
    "tech-q-3":"Daily_FE_Web_Frameworks",
    "tech-q-4":"Wanted_FE_Web_Frameworks",
    "tech-q-5":"Daily_BE_Web_Frameworks",
    "tech-q-6":"Wanted_BE_Web_Frameworks",
    "tech-q-7":"Daily_Paltforms",
    "tech-q-8":"Wanted_Platforms",
    "tech-q-9":"Primary_OS",
    "tech-q-10":"Daily_IDE",
    "tech-q-11":"Continuous_Learning_Frequency",
    "tech-q-12":"Help_Sources",
    "tech-q-13":"Production_Env_Used",
    "tech-q-14":"Cloud_Platform_Used",
    "tech-q-15":"Production_DB_Used",
    "tech-q-16":"AI_Tools_Usage_Frequency",
    "work-q-0":"Employment_Status",
    "work-q-1":"Overtime_Frequency",
    "work-q-2":"Job_Satisfaction",
    "work-q-3":"Side_Projects",
    "work-q-4":"Graduation_Employment_Gap",
    "work-q-5":"CDI_Morocco_Salary_Range_DH",
    "work-q-6":"Freelancer_Morocco_Salary_Range_DH",
    "work-q-7":"CDI_Abroad_Salary_Range_USD",
    "work-q-8":"Freelancer_Abroad_Salary_Range_USD",
    "work-q-9":"Preferred_Job_Criteria",
    "work-q-10":"Preferred_Company_Type",
    "work-q-11":"Agile_Methodology",
    "work-q-12":"Provided_Work_Model",
    "work-q-13":"Prefrred_Work_Model",
    "community-q-0":"Local_Community_Membership",
    "community-q-1":"Open_Source_Participation",
    "community-q-2":"Blog_Posting",
    "community-q-3":"IT_Primary_Social_Network",
    "community-q-4":"Event_Attendence_20_21",
    "community-q-5":"Talks_Participation_20_21",
    "community-q-6":"Online_InPerson_Preferrence",
    "community-q-7":"Moroccan_Community_AutoEval",
}

# %%
# Save the Survey question codes as a new row
temp_df = pd.DataFrame(SOD_Morocco_qst.columns, columns=["Survey_Code"],
             index=SOD_Morocco_qst.columns).transpose()
SOD_Morocco_qst = pd.concat([SOD_Morocco_qst, temp_df])
del temp_df
# Replace the titles of columns in the Questions DataFrame
SOD_Morocco_qst.columns = SOD_Morocco_qst.columns.to_series().map(SOD_qst_dict)
SOD_Morocco_qst.head()
# Out:
#                            Gender  \
# multiple                    False
# label        What is your gender?
# required                     True
# choices            [Male, Female]
# Survey_Code           profile-q-0
#
#                                                            Age  \
# multiple                                                  None
# label                                        What is your age?
# required                                                  True
# choices      [Younger than 18 years, 18 to 24 years, 25 to ...
# Survey_Code                                        profile-q-1
#
#                                                        Country  \
# multiple                                                  None
# label                         Where are you currently located?
# required                                                  True
# choices      [Rabat-Salé-Kénitra, Casablanca-Settat, Marrak...
# Survey_Code                                        profile-q-2
#
#                                                      Job_Title  \
# multiple                                                  None
# label                                 What is your occupation?
# required                                                  True
# choices      [Back-end developer, Full-stack developer, Fro...
# Survey_Code                                        profile-q-3
#
#                                                      Education  \
# multiple                                                  None
# label                            What is your highest diploma?
# required                                                  True
# choices      [Self-taught, Bac +2/+3, Bachelor’s degree (B....
# Survey_Code                                        profile-q-4
#
#                                              Coding_Experience  \
# multiple                                                  None
# label        How many years have you been coding profession...
# required                                                  True
# choices      [I don't have any professional coding experien...
# Survey_Code                                        profile-q-5
#
#                         Coding_as_Hobby  \
# multiple                           None
# label        Is coding a hobby for you?
# required                           True
# choices                       [Yes, No]
# Survey_Code                 profile-q-6
#
#                                              Immigration_Plans  \
# multiple                                                  None
# label           Do you have any plans to work outside Morocco?
# required                                                  True
# choices      [Yes, in the next 12 months, Yes, in the next ...
# Survey_Code                                        profile-q-7
#
#                                                 Reentery_Plans  \
# multiple                                                  None
# label        If you are working abroad, do you have any pla...
# required                                                   NaN
# choices                            [Yes, Still hesitating, No]
# Survey_Code                                        profile-q-8
#
#                                              Fav_Coding_Drink  ...  \
# multiple                                                 None  ...
# label                 What do you usually drink while coding?  ...
# required                                                 True  ...
# choices      [Tea, Coffee, Water, Energy drinks, None, Other]  ...
# Survey_Code                                       profile-q-9  ...
#
#                                             Production_DB_Used  \
# multiple                                                  True
# label        The production database you or your team are u...
# required                                                   NaN
# choices      [Oracle Database, Mysql/MariaDB, PostgreSQL, S...
# Survey_Code                                          tech-q-15
#
#                                       AI_Tools_Usage_Frequency  \
# multiple                                                  None
# label        How often do you use AI tools for Dev (Github ...
# required                                                  True
# choices          [Daily, Tried them but not interested, Never]
# Survey_Code                                          tech-q-16
#
#                                     Local_Community_Membership  \
# multiple                                                 False
# label        How far are you involved in any local develope...
# required                                                  True
# choices      [No, I am not interested, I know some, but not...
# Survey_Code                                      community-q-0
#
#                                      Open_Source_Participation  \
# multiple                                                  True
# label        Did you ever participate in an open-source pro...
# required                                                  True
# choices      [I don’t have an account on Github (or alterna...
# Survey_Code                                      community-q-1
#
#                                                   Blog_Posting  \
# multiple                                                  None
# label              Did you get the chance to write blog posts?
# required                                                  True
# choices      [No, I am not interested., Still thinking abou...
# Survey_Code                                      community-q-2
#
#                                      IT_Primary_Social_Network  \
# multiple                                                 False
# label        When it comes to IT, what is your primary soci...
# required                                                  True
# choices      [Facebook, Instagram, WhatsApp, Twitter, Youtu...
# Survey_Code                                      community-q-3
#
#                                         Event_Attendence_20_21  \
# multiple                                                  None
# label        How many IT events did you attend in the last ...
# required                                                  True
# choices                                  [0, 1-3, More than 3]
# Survey_Code                                      community-q-4
#
#                                      Talks_Participation_20_21  \
# multiple                                                  None
# label        How many talks did you participate in the last...
# required                                                  True
# choices                          [0, 1 - 3 talks, More than 3]
# Survey_Code                                      community-q-5
#
#                                    Online_InPerson_Preferrence  \
# multiple                                                  None
# label                                           Do you prefer?
# required                                                  True
# choices      [Live/online events, In-person events?, Li ja ...
# Survey_Code                                      community-q-6
#
#                                   Moroccan_Community_AutoEval
# multiple                                                 None
# label        How do you evaluate the Moroccan Tech Community?
# required                                                 True
# choices                       [Bad, Not Bad, Good, Excellent]
# Survey_Code                                     community-q-7
#
# [5 rows x 56 columns]

# %%
# Replace the titles of columns in the Answers DataFrame
# ".map" makes an exhaustive repalcement by default
# Adding ".fillna" to keep the original column name if the mapping fails
SOD_Morocco.columns = SOD_Morocco.columns.to_series().map(SOD_qst_dict).fillna(SOD_Morocco.columns.to_series())
SOD_Morocco.head()
# Out:
#                          userId  Moroccan_Community_AutoEval  \
# 0  034cxKbcScSkMKWBkhu9xC6ubRE2                          2.0
# 1  04TsCbQGWxg9S2cudIT86e0CMH03                          3.0
# 2  05THu8aCmBUOnxCCGXESKeqlcVQ2                          3.0
# 3  06zWHRXkimdBlINCzJ3warn55V53                          NaN
# 4  08A0JzKQixVjdjCE49QboELB1do1                          NaN
#
#    IT_Primary_Social_Network          Wanted_Platforms  Job_Title  \
# 0                        4.0  [0, 1, 7, 9, 10, 12, 17]        4.0
# 1                        4.0                    [1, 9]        1.0
# 2                        0.0                      [19]       10.0
# 3                        NaN                       NaN       13.0
# 4                        NaN                       NaN        2.0
#
#    Immigration_Plans Open_Source_Participation  Country  Education  \
# 0                1.0                       [2]      3.0        1.0
# 1                0.0                       [0]      3.0        1.0
# 2                4.0                       [0]      1.0        1.0
# 3                4.0                       NaN      5.0        1.0
# 4                3.0                       NaN      2.0        2.0
#
#        startTime  ... English_Barrier  Continuous_Learning_Frequency  \
# 0  1672917044607  ...             1.0                            0.0
# 1  1671819917339  ...             1.0                            1.0
# 2  1672216451960  ...             1.0                            3.0
# 3  1671789215475  ...             1.0                            NaN
# 4  1672386895995  ...             NaN                            NaN
#
#    Local_Dialect_Content     Fav_Programming_Languages  \
# 0                    0.0        [0, 1, 3, 4, 5, 9, 10]
# 1                    0.0  [0, 1, 2, 3, 4, 5, 6, 7, 10]
# 2                    2.0                           [1]
# 3                    0.0                           NaN
# 4                    NaN                           NaN
#
#    Daily_BE_Web_Frameworks Coding_Experience Read_Write_Languages  \
# 0                     None               0.0         [0, 2, 3, 4]
# 1                  [7, 12]               0.0            [0, 2, 3]
# 2                     None               0.0               [0, 3]
# 3                      NaN               1.0            [0, 2, 3]
# 4                      NaN               3.0                  NaN
#
#   AI_Tools_Usage_Frequency  Freelancer_Morocco_Salary_Range_DH  Age
# 0                      2.0                                 NaN  1.0
# 1                      0.0                                 7.0  2.0
# 2                      2.0                                 NaN  1.0
# 3                      NaN                                 NaN  1.0
# 4                      NaN                                 NaN  1.0
#
# [5 rows x 59 columns]

# %% [markdown]
# ### Translate the answers values

# %%
from math import nan
import sys
# Mapping the answer values to the original choices in the questions DataFrame
for col in SOD_Morocco_qst.columns:
    temp_dict = dict(
        zip(
            range(0, len(SOD_Morocco_qst[col]["choices"])), SOD_Morocco_qst.loc["choices", col]
        )
    )
    # Seperate single choice from multi choice answers
    if SOD_Morocco[col].dtype != object:
        SOD_Morocco[col] = SOD_Morocco[col].map(temp_dict)
    else:
        temp_list= []
        for i in SOD_Morocco.index:
            # Some Nan values exist, we check to skip them
            if type(SOD_Morocco[col][i]) is list:
                temp_list.append([temp_dict[x] for x in SOD_Morocco.loc[i, col]])
            else:
                temp_list.append(nan)
        SOD_Morocco[col] = pd.Series(temp_list, dtype = object)

# %%
SOD_Morocco.head()
# Out:
#                          userId Moroccan_Community_AutoEval  \
# 0  034cxKbcScSkMKWBkhu9xC6ubRE2                        Good
# 1  04TsCbQGWxg9S2cudIT86e0CMH03                   Excellent
# 2  05THu8aCmBUOnxCCGXESKeqlcVQ2                   Excellent
# 3  06zWHRXkimdBlINCzJ3warn55V53                         NaN
# 4  08A0JzKQixVjdjCE49QboELB1do1                         NaN
#
#   IT_Primary_Social_Network  \
# 0                   Youtube
# 1                   Youtube
# 2                  Facebook
# 3                       NaN
# 4                       NaN
#
#                                     Wanted_Platforms  \
# 0  [Node.js, .NET, Docker, React Native, Unity 3D...
# 1                               [.NET, React Native]
# 2                                            [Other]
# 3                                                NaN
# 4                                                NaN
#
#                                        Job_Title  \
# 0                               Mobile developer
# 1                           Full-stack developer
# 2                                       Designer
# 3  Data scientist or machine learning specialist
# 4                            Front-end developer
#
#                    Immigration_Plans  \
# 0         Yes, in the next 24 months
# 1         Yes, in the next 12 months
# 2                                 No
# 3                                 No
# 4  Currently working outside Morocco
#
#                            Open_Source_Participation  \
# 0                 [I am maintaining my own project.]
# 1  [I don’t have an account on Github (or alterna...
# 2  [I don’t have an account on Github (or alterna...
# 3                                                NaN
# 4                                                NaN
#
#                      Country  \
# 0  Tanger-Tétouan-Al Hoceïma
# 1  Tanger-Tétouan-Al Hoceïma
# 2          Casablanca-Settat
# 3                 Fès-Meknès
# 4             Marrakech-Safi
#
#                                            Education      startTime  ...  \
# 0  Bac +2/+3, Bachelor’s degree (B.A., B.S., B.En...  1672917044607  ...
# 1  Bac +2/+3, Bachelor’s degree (B.A., B.S., B.En...  1671819917339  ...
# 2  Bac +2/+3, Bachelor’s degree (B.A., B.S., B.En...  1672216451960  ...
# 3  Bac +2/+3, Bachelor’s degree (B.A., B.S., B.En...  1671789215475  ...
# 4  Bac +5, Master’s degree (M.A., M.S., M.Eng., M...  1672386895995  ...
#
#   English_Barrier Continuous_Learning_Frequency Local_Dialect_Content  \
# 0              No              Every few months                Spoken
# 1              No                   Once a year                Spoken
# 2              No                 Once a decade                  Both
# 3              No                           NaN                Spoken
# 4             NaN                           NaN                   NaN
#
#                            Fav_Programming_Languages Daily_BE_Web_Frameworks  \
# 0  [JavaScript, HTML/CSS 😉, Python, Java, Bash/Sh...                     NaN
# 1  [JavaScript, HTML/CSS 😉, SQL, Python, Java, Ba...   [Laravel, Express.js]
# 2                                       [HTML/CSS 😉]                     NaN
# 3                                                NaN                     NaN
# 4                                                NaN                     NaN
#
#                                  Coding_Experience  \
# 0  I don't have any professional coding experience
# 1  I don't have any professional coding experience
# 2  I don't have any professional coding experience
# 3                                 Less than a year
# 4                                        3-4 years
#
#                 Read_Write_Languages AI_Tools_Usage_Frequency  \
# 0  [Arabic, French, English, Others]                    Never
# 1          [Arabic, French, English]                    Daily
# 2                  [Arabic, English]                    Never
# 3          [Arabic, French, English]                      NaN
# 4                                NaN                      NaN
#
#   Freelancer_Morocco_Salary_Range_DH             Age
# 0                                NaN  18 to 24 years
# 1                            > 5 000  25 to 34 years
# 2                                NaN  18 to 24 years
# 3                                NaN  18 to 24 years
# 4                                NaN  18 to 24 years
#
# [5 rows x 59 columns]

# %%
SOD_Morocco_qst.head()
# Out:
#                            Gender  \
# multiple                    False
# label        What is your gender?
# required                     True
# choices            [Male, Female]
# Survey_Code           profile-q-0
#
#                                                            Age  \
# multiple                                                  None
# label                                        What is your age?
# required                                                  True
# choices      [Younger than 18 years, 18 to 24 years, 25 to ...
# Survey_Code                                        profile-q-1
#
#                                                        Country  \
# multiple                                                  None
# label                         Where are you currently located?
# required                                                  True
# choices      [Rabat-Salé-Kénitra, Casablanca-Settat, Marrak...
# Survey_Code                                        profile-q-2
#
#                                                      Job_Title  \
# multiple                                                  None
# label                                 What is your occupation?
# required                                                  True
# choices      [Back-end developer, Full-stack developer, Fro...
# Survey_Code                                        profile-q-3
#
#                                                      Education  \
# multiple                                                  None
# label                            What is your highest diploma?
# required                                                  True
# choices      [Self-taught, Bac +2/+3, Bachelor’s degree (B....
# Survey_Code                                        profile-q-4
#
#                                              Coding_Experience  \
# multiple                                                  None
# label        How many years have you been coding profession...
# required                                                  True
# choices      [I don't have any professional coding experien...
# Survey_Code                                        profile-q-5
#
#                         Coding_as_Hobby  \
# multiple                           None
# label        Is coding a hobby for you?
# required                           True
# choices                       [Yes, No]
# Survey_Code                 profile-q-6
#
#                                              Immigration_Plans  \
# multiple                                                  None
# label           Do you have any plans to work outside Morocco?
# required                                                  True
# choices      [Yes, in the next 12 months, Yes, in the next ...
# Survey_Code                                        profile-q-7
#
#                                                 Reentery_Plans  \
# multiple                                                  None
# label        If you are working abroad, do you have any pla...
# required                                                   NaN
# choices                            [Yes, Still hesitating, No]
# Survey_Code                                        profile-q-8
#
#                                              Fav_Coding_Drink  ...  \
# multiple                                                 None  ...
# label                 What do you usually drink while coding?  ...
# required                                                 True  ...
# choices      [Tea, Coffee, Water, Energy drinks, None, Other]  ...
# Survey_Code                                       profile-q-9  ...
#
#                                             Production_DB_Used  \
# multiple                                                  True
# label        The production database you or your team are u...
# required                                                   NaN
# choices      [Oracle Database, Mysql/MariaDB, PostgreSQL, S...
# Survey_Code                                          tech-q-15
#
#                                       AI_Tools_Usage_Frequency  \
# multiple                                                  None
# label        How often do you use AI tools for Dev (Github ...
# required                                                  True
# choices          [Daily, Tried them but not interested, Never]
# Survey_Code                                          tech-q-16
#
#                                     Local_Community_Membership  \
# multiple                                                 False
# label        How far are you involved in any local develope...
# required                                                  True
# choices      [No, I am not interested, I know some, but not...
# Survey_Code                                      community-q-0
#
#                                      Open_Source_Participation  \
# multiple                                                  True
# label        Did you ever participate in an open-source pro...
# required                                                  True
# choices      [I don’t have an account on Github (or alterna...
# Survey_Code                                      community-q-1
#
#                                                   Blog_Posting  \
# multiple                                                  None
# label              Did you get the chance to write blog posts?
# required                                                  True
# choices      [No, I am not interested., Still thinking abou...
# Survey_Code                                      community-q-2
#
#                                      IT_Primary_Social_Network  \
# multiple                                                 False
# label        When it comes to IT, what is your primary soci...
# required                                                  True
# choices      [Facebook, Instagram, WhatsApp, Twitter, Youtu...
# Survey_Code                                      community-q-3
#
#                                         Event_Attendence_20_21  \
# multiple                                                  None
# label        How many IT events did you attend in the last ...
# required                                                  True
# choices                                  [0, 1-3, More than 3]
# Survey_Code                                      community-q-4
#
#                                      Talks_Participation_20_21  \
# multiple                                                  None
# label        How many talks did you participate in the last...
# required                                                  True
# choices                          [0, 1 - 3 talks, More than 3]
# Survey_Code                                      community-q-5
#
#                                    Online_InPerson_Preferrence  \
# multiple                                                  None
# label                                           Do you prefer?
# required                                                  True
# choices      [Live/online events, In-person events?, Li ja ...
# Survey_Code                                      community-q-6
#
#                                   Moroccan_Community_AutoEval
# multiple                                                 None
# label        How do you evaluate the Moroccan Tech Community?
# required                                                 True
# choices                       [Bad, Not Bad, Good, Excellent]
# Survey_Code                                     community-q-7
#
# [5 rows x 56 columns]

# %% [markdown]
# ### Remove Empty users

# %%
# The data needs to be cleaned, some submitters/objects are empty
# You'll find the list of userId missing data below (253 users)
SOD_Morocco[SOD_Morocco['Gender'].isnull()]
# Out:
#                             userId Moroccan_Community_AutoEval  \
# 11    0LMR7zjT1BNr2AD0sPPkUvWKjh82                         NaN
# 54    1lMPJiLYinO6kOC7rck2bq6Pgwq1                         NaN
# 57    1vtKBZU40ZfOphG4sGs1b9xjDL33                         NaN
# 58    1y5p0vwqbCRJAWllKaqN5ZFUbHy2                         NaN
# 60    21LIp341cNM90idrvtkDWSAzrQm1                         NaN
# ...                            ...                         ...
# 1952  z7xb8CTUWBWAcgAboIB5reKNiRD2                         NaN
# 1954  zC7P3u7c92ZnhLeroR8KdzNwVDF2                         NaN
# 1959  zQj0iQFsMjPC4QX5LJklNXDlBI93                         NaN
# 1974  zpRBRZZOCrasGDRRvTK7kc0cyHp2                         NaN
# 1977  zvXEH7yiE2djWHQXJnzRot11EX83                         NaN
#
#      IT_Primary_Social_Network Wanted_Platforms Job_Title Immigration_Plans  \
# 11                         NaN              NaN       NaN               NaN
# 54                         NaN              NaN       NaN               NaN
# 57                         NaN              NaN       NaN               NaN
# 58                         NaN              NaN       NaN               NaN
# 60                         NaN              NaN       NaN               NaN
# ...                        ...              ...       ...               ...
# 1952                       NaN              NaN       NaN               NaN
# 1954                       NaN              NaN       NaN               NaN
# 1959                       NaN              NaN       NaN               NaN
# 1974                       NaN              NaN       NaN               NaN
# 1977                       NaN              NaN       NaN               NaN
#
#      Open_Source_Participation Country Education      startTime  ...  \
# 11                         NaN     NaN       NaN  1672826958615  ...
# 54                         NaN     NaN       NaN  1671471802233  ...
# 57                         NaN     NaN       NaN  1671967743464  ...
# 58                         NaN     NaN       NaN  1672937471013  ...
# 60                         NaN     NaN       NaN  1671653412868  ...
# ...                        ...     ...       ...            ...  ...
# 1952                       NaN     NaN       NaN  1674000001001  ...
# 1954                       NaN     NaN       NaN  1672518532681  ...
# 1959                       NaN     NaN       NaN  1672255214838  ...
# 1974                       NaN     NaN       NaN  1671781877524  ...
# 1977                       NaN     NaN       NaN  1673368266663  ...
#
#      English_Barrier Continuous_Learning_Frequency Local_Dialect_Content  \
# 11               NaN                           NaN                   NaN
# 54               NaN                           NaN                   NaN
# 57               NaN                           NaN                   NaN
# 58               NaN                           NaN                   NaN
# 60               NaN                           NaN                   NaN
# ...              ...                           ...                   ...
# 1952             NaN                           NaN                   NaN
# 1954             NaN                           NaN                   NaN
# 1959             NaN                           NaN                   NaN
# 1974             NaN                           NaN                   NaN
# 1977             NaN                           NaN                   NaN
#
#      Fav_Programming_Languages Daily_BE_Web_Frameworks Coding_Experience  \
# 11                         NaN                     NaN               NaN
# 54                         NaN                     NaN               NaN
# 57                         NaN                     NaN               NaN
# 58                         NaN                     NaN               NaN
# 60                         NaN                     NaN               NaN
# ...                        ...                     ...               ...
# 1952                       NaN                     NaN               NaN
# 1954                       NaN                     NaN               NaN
# 1959                       NaN                     NaN               NaN
# 1974                       NaN                     NaN               NaN
# 1977                       NaN                     NaN               NaN
#
#      Read_Write_Languages AI_Tools_Usage_Frequency  \
# 11                    NaN                      NaN
# 54                    NaN                      NaN
# 57                    NaN                      NaN
# 58                    NaN                      NaN
# 60                    NaN                      NaN
# ...                   ...                      ...
# 1952                  NaN                      NaN
# 1954                  NaN                      NaN
# 1959                  NaN                      NaN
# 1974                  NaN                      NaN
# 1977                  NaN                      NaN
#
#      Freelancer_Morocco_Salary_Range_DH  Age
# 11                                  NaN  NaN
# 54                                  NaN  NaN
# 57                                  NaN  NaN
# 58                                  NaN  NaN
# 60                                  NaN  NaN
# ...                                 ...  ...
# 1952                                NaN  NaN
# 1954                                NaN  NaN
# 1959                                NaN  NaN
# 1974                                NaN  NaN
# 1977                                NaN  NaN
#
# [367 rows x 59 columns]

# %%
# Number of submitters before cleaning the data
SOD_Morocco.shape[0]
# Out:
# 1984

# %%
# Remove them from the dataset
SOD_Morocco = SOD_Morocco[SOD_Morocco['Gender'].notna()]

# %%
# Number of submitters after cleaning the data
SOD_Morocco.shape[0]
# Out:
# 1617

# %% [markdown]
# ### Save to CSV

# %%
SOD_Morocco.to_csv("results_preprocessed.csv", index = False)
# Choosing to keep the Index for the Answers DataFrame
SOD_Morocco_qst.to_csv("questions_preprocessed.csv", index_label ="Keys" )
