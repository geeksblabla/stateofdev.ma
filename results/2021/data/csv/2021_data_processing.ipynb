# %% [markdown]
# # Simple Pre-Processing for the Raw results
# This notebook applies some basic preproccessing on the raw survey results, mainly:
# - Transforming the "JSON" files into "CSV" which is more friendly and common for data analysis tasks.
# - Decoding the questions and answers values to natural language categories, in order to use for future work.
#
# **Let's GO!**

# %% [markdown]
# ### Imports

# %%
import pandas as pd 
import json

# %% [markdown]
# ### Read the Json Files

# %%
with open('./../results.json') as f:
    data = json.load(f)
SOD_Morocco = pd.DataFrame(data['results'])
SOD_Morocco.head()
# Out:
#                          userId  community-q-6  profile-q-0  \
# 0  01BV48HMOShv1AYfUrsb8yObpdK2            0.0          0.0
# 1  01CNPyUuqBXvSlbwMeuoSOoh2Sg1            2.0          0.0
# 2  02855LEtvnh8H6o6xeU8pRbER2s1            NaN          NaN
# 3  032il0r4EzeudubezmM1kFr6SLj2            1.0          0.0
# 4  09vEQWutBeYMv1MjCJgLl0vJmLT2            NaN          0.0
#
#            education-q-6  work-q-0  profile-q-6 education-q-3    tech-q-5  \
# 0              [0, 3, 9]       1.0          0.0     [0, 2, 3]          []
# 1     [0, 2, 3, 4, 6, 8]       1.0          0.0  [0, 2, 3, 4]  [5, 6, 18]
# 2                    NaN       NaN          NaN           NaN         NaN
# 3  [0, 1, 2, 3, 4, 5, 8]       6.0          0.0     [0, 2, 3]      [1, 4]
# 4              [0, 1, 8]       NaN          0.0        [0, 3]         NaN
#
#    work-q-6 community-q-1  ...     startTime  work-q-2  work-q-10  \
# 0       5.0           [0]  ...  1.637612e+12       4.0        4.0
# 1       NaN           [2]  ...  1.636550e+12       4.0        3.0
# 2       NaN           NaN  ...  1.638973e+12       NaN        NaN
# 3       NaN           [2]  ...  1.636925e+12       NaN        3.0
# 4       NaN           NaN  ...  1.638035e+12       NaN        NaN
#
#      lastSubmit profile-q-5 education-q-1  community-q-3 community-q-5  \
# 0  1.637613e+12         5.0           0.0            9.0           1.0
# 1  1.636551e+12         3.0           1.0            7.0           0.0
# 2           NaN         NaN           NaN            NaN           NaN
# 3  1.636926e+12         1.0           0.0            9.0           0.0
# 4  1.638035e+12         0.0           0.0            NaN           NaN
#
#   tech-q-6  work-q-12
# 0       []        2.0
# 1       []        2.0
# 2      NaN        NaN
# 3      [5]        NaN
# 4      NaN        NaN
#
# [5 rows x 58 columns]

# %%
SOD_Morocco_qst = pd.read_json("./../questions.json")
SOD_Morocco_qst.head()
# Out:
#                    profile-q-0  \
# multiple                 False
# label     What is your gender?
# required                  True
# choices         [Male, Female]
#
#                                                 profile-q-1  \
# multiple                                               None
# label                                     What is your age?
# required                                               True
# choices   [Younger than 18 years, 18 to 24 years, 25 to ...
#
#                                                 profile-q-2  \
# multiple                                               None
# label                      Where are you currently located?
# required                                               True
# choices   [Rabat-Salé-Kénitra, Casablanca-Settat, Marrak...
#
#                                                 profile-q-3  \
# multiple                                               None
# label                              What is your occupation?
# required                                               True
# choices   [Back-end developer, Full-stack developer, Fro...
#
#                                                 profile-q-4  \
# multiple                                               None
# label                         What is your highest diploma?
# required                                               True
# choices   [Self-taught, Bac +2/+3, Bachelor’s degree (B....
#
#                                                 profile-q-5  \
# multiple                                               None
# label     How many years have you been coding profession...
# required                                               True
# choices   [I don't have any professional coding experien...
#
#                          profile-q-6  \
# multiple                        None
# label     Is coding a hobby for you?
# required                        True
# choices                    [Yes, No]
#
#                                                 profile-q-7  \
# multiple                                               None
# label        Do you have any plans to work outside Morocco?
# required                                               True
# choices   [Yes, in the next 12 months, Yes, in the next ...
#
#                                                 profile-q-8  \
# multiple                                               None
# label     If you are working abroad, do you have any pla...
# required                                                NaN
# choices                         [Yes, Still hesitating, No]
#
#                                                profile-q-9  ...  \
# multiple                                              None  ...
# label              What do you usually drink while coding?  ...
# required                                              True  ...
# choices   [Tea, Coffee, Water, Energy drinks, None, Other]  ...
#
#                                                   tech-q-14  \
# multiple                                               True
# label                    What cloud platform are you using?
# required                                                NaN
# choices   [GCP, AWS, Azure, Oracle Cloud, IBM Cloud, Dig...
#
#                                                   tech-q-15  \
# multiple                                               True
# label     The production database you or your team are u...
# required                                                NaN
# choices   [Oracle Database, Mysql/MariaDB, PostgreSQL, S...
#
#                                               community-q-0  \
# multiple                                              False
# label     How far are you involved in any local develope...
# required                                               True
# choices   [No, I am not interested, I know some, but not...
#
#                                               community-q-1  \
# multiple                                               True
# label     Did you ever participate in an open-source pro...
# required                                               True
# choices   [I don’t have an account on Github (or alterna...
#
#                                               community-q-2  \
# multiple                                               None
# label           Did you get the chance to write blog posts?
# required                                               True
# choices   [No, I am not interested., Still thinking abou...
#
#                                               community-q-3  \
# multiple                                              False
# label     When it comes to IT, what is your primary soci...
# required                                               True
# choices   [Facebook, Instagram, WhatsApp, Twitter, Youtu...
#
#                                             community-q-4  \
# multiple                                             None
# label     How many IT events did you attend in 2020/2021?
# required                                             True
# choices                             [0, 1-3, More than 3]
#
#                                               community-q-5  \
# multiple                                               None
# label     How many talks did you participate in as a spe...
# required                                               True
# choices                       [0, 1 - 3 talks, More than 3]
#
#                                               community-q-6  \
# multiple                                               None
# label                                        Do you prefer?
# required                                               True
# choices   [Live/online events, In-person events?, Li ja ...
#
#                                              community-q-7
# multiple                                              None
# label     How do you evaluate the Moroccan Tech Community?
# required                                              True
# choices                    [Bad, Not Bad, Good, Excellent]
#
# [4 rows x 55 columns]

# %% [markdown]
# ### Translate the survey codes and abbreviations

# %%
SOD_qst_dict = {
    "profile-q-0":"Gender",
    "profile-q-1":"Age", 
    "profile-q-2":"Country",
    "profile-q-3":"Job_Title",
    "profile-q-4":"Education",
    "profile-q-5":"Coding_Experience",
    "profile-q-6":"Coding_as_Hobby",
    "profile-q-7":"Immigration_Plans",
    "profile-q-8":"Reentery_Plans",
    "profile-q-9":"Fav_Coding_Drink",
    "education-q-0":"Coding_Education",
    "education-q-1":"Teaching_Jobs_Gap",
    "education-q-2":"Teaching_Problems_POV",
    "education-q-3":"Read_Write_Languages",
    "education-q-4":"English_Barrier",
    "education-q-5":"Local_Dialect_Content",
    "education-q-6":"Learning_Platforms",
    "tech-q-0":"Fav_Programming_Languages",
    "tech-q-1":"Wanted_Programming_Languages",
    "tech-q-2":"Daily_Programming_Languages",
    "tech-q-3":"Daily_FE_Web_Frameworks",
    "tech-q-4":"Wanted_FE_Web_Frameworks",
    "tech-q-5":"Daily_BE_Web_Frameworks",
    "tech-q-6":"Wanted_BE_Web_Frameworks",
    "tech-q-7":"Daily_Paltforms",
    "tech-q-8":"Wanted_Platforms",
    "tech-q-9":"Primary_OS",
    "tech-q-10":"Daily_IDE",
    "tech-q-11":"Continuous_Learning_Frequency",
    "tech-q-12":"Help_Sources",
    "tech-q-13":"Production_Env_Used",
    "tech-q-14":"Cloud_Platform_Used",
    "tech-q-15":"Production_DB_Used",
    "work-q-0":"Employment_Status",
    "work-q-1":"Overtime_Frequency",
    "work-q-2":"Job_Satisfaction",
    "work-q-3":"Side_Projects",
    "work-q-4":"Graduation_Employment_Gap",
    "work-q-5":"CDI_Morocco_Salary_Range_DH",
    "work-q-6":"Freelancer_Morocco_Salary_Range_DH",
    "work-q-7":"CDI_Abroad_Salary_Range_USD",
    "work-q-8":"Freelancer_Abroad_Salary_Range_USD",
    "work-q-9":"Preferred_Job_Criteria",
    "work-q-10":"Preferred_Company_Type",
    "work-q-11":"Agile_Methodology",
    "work-q-12":"Provided_Work_Model",
    "work-q-13":"Prefrred_Work_Model",
    "community-q-0":"Local_Community_Membership",
    "community-q-1":"Open_Source_Participation",
    "community-q-2":"Blog_Posting",
    "community-q-3":"IT_Primary_Social_Network",
    "community-q-4":"Event_Attendence_20_21",
    "community-q-5":"Talks_Participation_20_21",
    "community-q-6":"Online_InPerson_Preferrence",
    "community-q-7":"Moroccan_Community_AutoEval",
}

# %%
# Save the Survey question codes as a new row
temp_df = pd.DataFrame(SOD_Morocco_qst.columns, columns=["Survey_Code"],
             index=SOD_Morocco_qst.columns).transpose()
SOD_Morocco_qst = pd.concat([SOD_Morocco_qst, temp_df])
del temp_df
# Replace the titles of columns in the Questions DataFrame
SOD_Morocco_qst.columns = SOD_Morocco_qst.columns.to_series().map(SOD_qst_dict)
SOD_Morocco_qst.head()
# Out:
#                            Gender  \
# multiple                    False
# label        What is your gender?
# required                     True
# choices            [Male, Female]
# Survey_Code           profile-q-0
#
#                                                            Age  \
# multiple                                                  None
# label                                        What is your age?
# required                                                  True
# choices      [Younger than 18 years, 18 to 24 years, 25 to ...
# Survey_Code                                        profile-q-1
#
#                                                        Country  \
# multiple                                                  None
# label                         Where are you currently located?
# required                                                  True
# choices      [Rabat-Salé-Kénitra, Casablanca-Settat, Marrak...
# Survey_Code                                        profile-q-2
#
#                                                      Job_Title  \
# multiple                                                  None
# label                                 What is your occupation?
# required                                                  True
# choices      [Back-end developer, Full-stack developer, Fro...
# Survey_Code                                        profile-q-3
#
#                                                      Education  \
# multiple                                                  None
# label                            What is your highest diploma?
# required                                                  True
# choices      [Self-taught, Bac +2/+3, Bachelor’s degree (B....
# Survey_Code                                        profile-q-4
#
#                                              Coding_Experience  \
# multiple                                                  None
# label        How many years have you been coding profession...
# required                                                  True
# choices      [I don't have any professional coding experien...
# Survey_Code                                        profile-q-5
#
#                         Coding_as_Hobby  \
# multiple                           None
# label        Is coding a hobby for you?
# required                           True
# choices                       [Yes, No]
# Survey_Code                 profile-q-6
#
#                                              Immigration_Plans  \
# multiple                                                  None
# label           Do you have any plans to work outside Morocco?
# required                                                  True
# choices      [Yes, in the next 12 months, Yes, in the next ...
# Survey_Code                                        profile-q-7
#
#                                                 Reentery_Plans  \
# multiple                                                  None
# label        If you are working abroad, do you have any pla...
# required                                                   NaN
# choices                            [Yes, Still hesitating, No]
# Survey_Code                                        profile-q-8
#
#                                              Fav_Coding_Drink  ...  \
# multiple                                                 None  ...
# label                 What do you usually drink while coding?  ...
# required                                                 True  ...
# choices      [Tea, Coffee, Water, Energy drinks, None, Other]  ...
# Survey_Code                                       profile-q-9  ...
#
#                                            Cloud_Platform_Used  \
# multiple                                                  True
# label                       What cloud platform are you using?
# required                                                   NaN
# choices      [GCP, AWS, Azure, Oracle Cloud, IBM Cloud, Dig...
# Survey_Code                                          tech-q-14
#
#                                             Production_DB_Used  \
# multiple                                                  True
# label        The production database you or your team are u...
# required                                                   NaN
# choices      [Oracle Database, Mysql/MariaDB, PostgreSQL, S...
# Survey_Code                                          tech-q-15
#
#                                     Local_Community_Membership  \
# multiple                                                 False
# label        How far are you involved in any local develope...
# required                                                  True
# choices      [No, I am not interested, I know some, but not...
# Survey_Code                                      community-q-0
#
#                                      Open_Source_Participation  \
# multiple                                                  True
# label        Did you ever participate in an open-source pro...
# required                                                  True
# choices      [I don’t have an account on Github (or alterna...
# Survey_Code                                      community-q-1
#
#                                                   Blog_Posting  \
# multiple                                                  None
# label              Did you get the chance to write blog posts?
# required                                                  True
# choices      [No, I am not interested., Still thinking abou...
# Survey_Code                                      community-q-2
#
#                                      IT_Primary_Social_Network  \
# multiple                                                 False
# label        When it comes to IT, what is your primary soci...
# required                                                  True
# choices      [Facebook, Instagram, WhatsApp, Twitter, Youtu...
# Survey_Code                                      community-q-3
#
#                                       Event_Attendence_20_21  \
# multiple                                                None
# label        How many IT events did you attend in 2020/2021?
# required                                                True
# choices                                [0, 1-3, More than 3]
# Survey_Code                                    community-q-4
#
#                                      Talks_Participation_20_21  \
# multiple                                                  None
# label        How many talks did you participate in as a spe...
# required                                                  True
# choices                          [0, 1 - 3 talks, More than 3]
# Survey_Code                                      community-q-5
#
#                                    Online_InPerson_Preferrence  \
# multiple                                                  None
# label                                           Do you prefer?
# required                                                  True
# choices      [Live/online events, In-person events?, Li ja ...
# Survey_Code                                      community-q-6
#
#                                   Moroccan_Community_AutoEval
# multiple                                                 None
# label        How do you evaluate the Moroccan Tech Community?
# required                                                 True
# choices                       [Bad, Not Bad, Good, Excellent]
# Survey_Code                                     community-q-7
#
# [5 rows x 55 columns]

# %%
# Replace the titles of columns in the Answers DataFrame
# ".map" makes an exhaustive repalcement by default
# Adding ".fillna" to keep the original column name if the mapping fails
SOD_Morocco.columns = SOD_Morocco.columns.to_series().map(SOD_qst_dict).fillna(SOD_Morocco.columns.to_series())
SOD_Morocco.head()
# Out:
#                          userId  Online_InPerson_Preferrence  Gender  \
# 0  01BV48HMOShv1AYfUrsb8yObpdK2                          0.0     0.0
# 1  01CNPyUuqBXvSlbwMeuoSOoh2Sg1                          2.0     0.0
# 2  02855LEtvnh8H6o6xeU8pRbER2s1                          NaN     NaN
# 3  032il0r4EzeudubezmM1kFr6SLj2                          1.0     0.0
# 4  09vEQWutBeYMv1MjCJgLl0vJmLT2                          NaN     0.0
#
#       Learning_Platforms  Employment_Status  Coding_as_Hobby  \
# 0              [0, 3, 9]                1.0              0.0
# 1     [0, 2, 3, 4, 6, 8]                1.0              0.0
# 2                    NaN                NaN              NaN
# 3  [0, 1, 2, 3, 4, 5, 8]                6.0              0.0
# 4              [0, 1, 8]                NaN              0.0
#
#   Read_Write_Languages Daily_BE_Web_Frameworks  \
# 0            [0, 2, 3]                      []
# 1         [0, 2, 3, 4]              [5, 6, 18]
# 2                  NaN                     NaN
# 3            [0, 2, 3]                  [1, 4]
# 4               [0, 3]                     NaN
#
#    Freelancer_Morocco_Salary_Range_DH Open_Source_Participation  ...  \
# 0                                 5.0                       [0]  ...
# 1                                 NaN                       [2]  ...
# 2                                 NaN                       NaN  ...
# 3                                 NaN                       [2]  ...
# 4                                 NaN                       NaN  ...
#
#       startTime  Job_Satisfaction  Preferred_Company_Type    lastSubmit  \
# 0  1.637612e+12               4.0                     4.0  1.637613e+12
# 1  1.636550e+12               4.0                     3.0  1.636551e+12
# 2  1.638973e+12               NaN                     NaN           NaN
# 3  1.636925e+12               NaN                     3.0  1.636926e+12
# 4  1.638035e+12               NaN                     NaN  1.638035e+12
#
#   Coding_Experience Teaching_Jobs_Gap  IT_Primary_Social_Network  \
# 0               5.0               0.0                        9.0
# 1               3.0               1.0                        7.0
# 2               NaN               NaN                        NaN
# 3               1.0               0.0                        9.0
# 4               0.0               0.0                        NaN
#
#   Talks_Participation_20_21 Wanted_BE_Web_Frameworks  Provided_Work_Model
# 0                       1.0                       []                  2.0
# 1                       0.0                       []                  2.0
# 2                       NaN                      NaN                  NaN
# 3                       0.0                      [5]                  NaN
# 4                       NaN                      NaN                  NaN
#
# [5 rows x 58 columns]

# %% [markdown]
# ### Translate the answers values

# %%
from math import nan
import sys
# Mapping the answer values to the original choices in the questions DataFrame
for col in SOD_Morocco_qst.columns:
    temp_dict = dict(
        zip(
            range(0, len(SOD_Morocco_qst[col]["choices"])), SOD_Morocco_qst.loc["choices", col]
        )
    )
    # Seperate single choice from multi choice answers
    if SOD_Morocco[col].dtype != object:
        SOD_Morocco[col] = SOD_Morocco[col].map(temp_dict)
    else:
        temp_list= []
        for i in SOD_Morocco.index:
            # Some Nan values exist, we check to skip them
            if type(SOD_Morocco[col][i]) is list:
                temp_list.append([temp_dict[x] for x in SOD_Morocco.loc[i, col]])
            else:
                temp_list.append(nan)
        SOD_Morocco[col] = pd.Series(temp_list, dtype = object)

# %%
SOD_Morocco.head()
# Out:
#                          userId Online_InPerson_Preferrence Gender  \
# 0  01BV48HMOShv1AYfUrsb8yObpdK2          Live/online events   Male
# 1  01CNPyUuqBXvSlbwMeuoSOoh2Sg1             Li ja bismillah   Male
# 2  02855LEtvnh8H6o6xeU8pRbER2s1                         NaN    NaN
# 3  032il0r4EzeudubezmM1kFr6SLj2           In-person events?   Male
# 4  09vEQWutBeYMv1MjCJgLl0vJmLT2                         NaN   Male
#
#                                   Learning_Platforms   Employment_Status  \
# 0          [YouTube, Official documentation, Others]  Employed full-time
# 1  [YouTube, Books, Official documentation, Blog ...  Employed full-time
# 2                                                NaN                 NaN
# 3  [YouTube, Paid platforms, Books, Official docu...             Student
# 4  [YouTube, Paid platforms, Online Communities (...                 NaN
#
#   Coding_as_Hobby               Read_Write_Languages  \
# 0             Yes          [Arabic, French, English]
# 1             Yes  [Arabic, French, English, Others]
# 2             NaN                                NaN
# 3             Yes          [Arabic, French, English]
# 4             Yes                  [Arabic, English]
#
#                     Daily_BE_Web_Frameworks  \
# 0                                        []
# 1                    [Django, Flask, Other]
# 2                                       NaN
# 3  [Spring Ecosystem, Jakarta EE / Java EE]
# 4                                       NaN
#
#   Freelancer_Morocco_Salary_Range_DH  \
# 0                      3 000 - 4 000
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
#                            Open_Source_Participation  ...     startTime  \
# 0  [I don’t have an account on Github (or alterna...  ...  1.637612e+12
# 1                 [I am maintaining my own project.]  ...  1.636550e+12
# 2                                                NaN  ...  1.638973e+12
# 3                 [I am maintaining my own project.]  ...  1.636925e+12
# 4                                                NaN  ...  1.638035e+12
#
#   Job_Satisfaction               Preferred_Company_Type    lastSubmit  \
# 0   Very satisfied          Company with >100 employees  1.637613e+12
# 1   Very satisfied  Company with >30 and <100 employees  1.636551e+12
# 2              NaN                                  NaN           NaN
# 3              NaN  Company with >30 and <100 employees  1.636926e+12
# 4              NaN                                  NaN  1.638035e+12
#
#                                  Coding_Experience Teaching_Jobs_Gap  \
# 0                                       7-10 years        Not enough
# 1                                        3-4 years   Enough to start
# 2                                              NaN               NaN
# 3                                 Less than a year        Not enough
# 4  I don't have any professional coding experience        Not enough
#
#   IT_Primary_Social_Network Talks_Participation_20_21  \
# 0                      None               1 - 3 talks
# 1                     Slack                         0
# 2                       NaN                       NaN
# 3                      None                         0
# 4                       NaN                       NaN
#
#   Wanted_BE_Web_Frameworks Provided_Work_Model
# 0                       []              Hybrid
# 1                       []              Hybrid
# 2                      NaN                 NaN
# 3                 [Django]                 NaN
# 4                      NaN                 NaN
#
# [5 rows x 58 columns]

# %%
SOD_Morocco_qst.head()
# Out:
#                            Gender  \
# multiple                    False
# label        What is your gender?
# required                     True
# choices            [Male, Female]
# Survey_Code           profile-q-0
#
#                                                            Age  \
# multiple                                                  None
# label                                        What is your age?
# required                                                  True
# choices      [Younger than 18 years, 18 to 24 years, 25 to ...
# Survey_Code                                        profile-q-1
#
#                                                        Country  \
# multiple                                                  None
# label                         Where are you currently located?
# required                                                  True
# choices      [Rabat-Salé-Kénitra, Casablanca-Settat, Marrak...
# Survey_Code                                        profile-q-2
#
#                                                      Job_Title  \
# multiple                                                  None
# label                                 What is your occupation?
# required                                                  True
# choices      [Back-end developer, Full-stack developer, Fro...
# Survey_Code                                        profile-q-3
#
#                                                      Education  \
# multiple                                                  None
# label                            What is your highest diploma?
# required                                                  True
# choices      [Self-taught, Bac +2/+3, Bachelor’s degree (B....
# Survey_Code                                        profile-q-4
#
#                                              Coding_Experience  \
# multiple                                                  None
# label        How many years have you been coding profession...
# required                                                  True
# choices      [I don't have any professional coding experien...
# Survey_Code                                        profile-q-5
#
#                         Coding_as_Hobby  \
# multiple                           None
# label        Is coding a hobby for you?
# required                           True
# choices                       [Yes, No]
# Survey_Code                 profile-q-6
#
#                                              Immigration_Plans  \
# multiple                                                  None
# label           Do you have any plans to work outside Morocco?
# required                                                  True
# choices      [Yes, in the next 12 months, Yes, in the next ...
# Survey_Code                                        profile-q-7
#
#                                                 Reentery_Plans  \
# multiple                                                  None
# label        If you are working abroad, do you have any pla...
# required                                                   NaN
# choices                            [Yes, Still hesitating, No]
# Survey_Code                                        profile-q-8
#
#                                              Fav_Coding_Drink  ...  \
# multiple                                                 None  ...
# label                 What do you usually drink while coding?  ...
# required                                                 True  ...
# choices      [Tea, Coffee, Water, Energy drinks, None, Other]  ...
# Survey_Code                                       profile-q-9  ...
#
#                                            Cloud_Platform_Used  \
# multiple                                                  True
# label                       What cloud platform are you using?
# required                                                   NaN
# choices      [GCP, AWS, Azure, Oracle Cloud, IBM Cloud, Dig...
# Survey_Code                                          tech-q-14
#
#                                             Production_DB_Used  \
# multiple                                                  True
# label        The production database you or your team are u...
# required                                                   NaN
# choices      [Oracle Database, Mysql/MariaDB, PostgreSQL, S...
# Survey_Code                                          tech-q-15
#
#                                     Local_Community_Membership  \
# multiple                                                 False
# label        How far are you involved in any local develope...
# required                                                  True
# choices      [No, I am not interested, I know some, but not...
# Survey_Code                                      community-q-0
#
#                                      Open_Source_Participation  \
# multiple                                                  True
# label        Did you ever participate in an open-source pro...
# required                                                  True
# choices      [I don’t have an account on Github (or alterna...
# Survey_Code                                      community-q-1
#
#                                                   Blog_Posting  \
# multiple                                                  None
# label              Did you get the chance to write blog posts?
# required                                                  True
# choices      [No, I am not interested., Still thinking abou...
# Survey_Code                                      community-q-2
#
#                                      IT_Primary_Social_Network  \
# multiple                                                 False
# label        When it comes to IT, what is your primary soci...
# required                                                  True
# choices      [Facebook, Instagram, WhatsApp, Twitter, Youtu...
# Survey_Code                                      community-q-3
#
#                                       Event_Attendence_20_21  \
# multiple                                                None
# label        How many IT events did you attend in 2020/2021?
# required                                                True
# choices                                [0, 1-3, More than 3]
# Survey_Code                                    community-q-4
#
#                                      Talks_Participation_20_21  \
# multiple                                                  None
# label        How many talks did you participate in as a spe...
# required                                                  True
# choices                          [0, 1 - 3 talks, More than 3]
# Survey_Code                                      community-q-5
#
#                                    Online_InPerson_Preferrence  \
# multiple                                                  None
# label                                           Do you prefer?
# required                                                  True
# choices      [Live/online events, In-person events?, Li ja ...
# Survey_Code                                      community-q-6
#
#                                   Moroccan_Community_AutoEval
# multiple                                                 None
# label        How do you evaluate the Moroccan Tech Community?
# required                                                 True
# choices                       [Bad, Not Bad, Good, Excellent]
# Survey_Code                                     community-q-7
#
# [5 rows x 55 columns]

# %% [markdown]
# ### Remove Empty users

# %%
# The data needs to be cleaned, some submitters/objects are empty
# You'll find the list of userId missing data below (253 users)
SOD_Morocco[SOD_Morocco['Gender'].isnull()]
# Out:
#                             userId Online_InPerson_Preferrence Gender  \
# 2     02855LEtvnh8H6o6xeU8pRbER2s1                         NaN    NaN
# 7     0IF3vGA0AwbxtOXPCT1c3rGRW093                         NaN    NaN
# 18    1PIk6rQT81aLjG5HhhOnQE8OfF12                         NaN    NaN
# 21    1X6tf7t29Ga5TaFfKr4yyIlQUOz1                         NaN    NaN
# 23    1bYuMhEx7QSUy99wHhikDyL10CJ3                         NaN    NaN
# ...                            ...                         ...    ...
# 1334  z7ZbvpwG4SQHo2nq4cXGOEdokh93                         NaN    NaN
# 1336  zAVATV2egGTMVjSmFK2HuE22dIF2                         NaN    NaN
# 1340  zOXPV1cYwQbKQM7zpY8vS6KByR93                         NaN    NaN
# 1346  zkqghvYFn6RiOKA5iU5wybeyRf12                         NaN    NaN
# 1350  zzjkjjbvx3MwKGr6hqcIO2J82Ir2                         NaN    NaN
#
#      Learning_Platforms Employment_Status Coding_as_Hobby  \
# 2                   NaN               NaN             NaN
# 7                   NaN               NaN             NaN
# 18                  NaN               NaN             NaN
# 21                  NaN               NaN             NaN
# 23                  NaN               NaN             NaN
# ...                 ...               ...             ...
# 1334                NaN               NaN             NaN
# 1336                NaN               NaN             NaN
# 1340                NaN               NaN             NaN
# 1346                NaN               NaN             NaN
# 1350                NaN               NaN             NaN
#
#      Read_Write_Languages Daily_BE_Web_Frameworks  \
# 2                     NaN                     NaN
# 7                     NaN                     NaN
# 18                    NaN                     NaN
# 21                    NaN                     NaN
# 23                    NaN                     NaN
# ...                   ...                     ...
# 1334                  NaN                     NaN
# 1336                  NaN                     NaN
# 1340                  NaN                     NaN
# 1346                  NaN                     NaN
# 1350                  NaN                     NaN
#
#      Freelancer_Morocco_Salary_Range_DH Open_Source_Participation  ...  \
# 2                                   NaN                       NaN  ...
# 7                                   NaN                       NaN  ...
# 18                                  NaN                       NaN  ...
# 21                                  NaN                       NaN  ...
# 23                                  NaN                       NaN  ...
# ...                                 ...                       ...  ...
# 1334                                NaN                       NaN  ...
# 1336                                NaN                       NaN  ...
# 1340                                NaN                       NaN  ...
# 1346                                NaN                       NaN  ...
# 1350                                NaN                       NaN  ...
#
#          startTime Job_Satisfaction Preferred_Company_Type lastSubmit  \
# 2     1.638973e+12              NaN                    NaN        NaN
# 7     1.636989e+12              NaN                    NaN        NaN
# 18    1.636471e+12              NaN                    NaN        NaN
# 21    1.636101e+12              NaN                    NaN        NaN
# 23    1.636424e+12              NaN                    NaN        NaN
# ...            ...              ...                    ...        ...
# 1334  1.638893e+12              NaN                    NaN        NaN
# 1336  1.636064e+12              NaN                    NaN        NaN
# 1340  1.636483e+12              NaN                    NaN        NaN
# 1346  1.636674e+12              NaN                    NaN        NaN
# 1350  1.636806e+12              NaN                    NaN        NaN
#
#      Coding_Experience Teaching_Jobs_Gap IT_Primary_Social_Network  \
# 2                  NaN               NaN                       NaN
# 7                  NaN               NaN                       NaN
# 18                 NaN               NaN                       NaN
# 21                 NaN               NaN                       NaN
# 23                 NaN               NaN                       NaN
# ...                ...               ...                       ...
# 1334               NaN               NaN                       NaN
# 1336               NaN               NaN                       NaN
# 1340               NaN               NaN                       NaN
# 1346               NaN               NaN                       NaN
# 1350               NaN               NaN                       NaN
#
#      Talks_Participation_20_21 Wanted_BE_Web_Frameworks Provided_Work_Model
# 2                          NaN                      NaN                 NaN
# 7                          NaN                      NaN                 NaN
# 18                         NaN                      NaN                 NaN
# 21                         NaN                      NaN                 NaN
# 23                         NaN                      NaN                 NaN
# ...                        ...                      ...                 ...
# 1334                       NaN                      NaN                 NaN
# 1336                       NaN                      NaN                 NaN
# 1340                       NaN                      NaN                 NaN
# 1346                       NaN                      NaN                 NaN
# 1350                       NaN                      NaN                 NaN
#
# [253 rows x 58 columns]

# %%
# Number of submitters before cleaning the data
SOD_Morocco.shape[0]
# Out:
# 1351

# %%
# Remove them from the dataset
SOD_Morocco = SOD_Morocco[SOD_Morocco['Gender'].notna()]

# %%
# Number of submitters after cleaning the data
SOD_Morocco.shape[0]
# Out:
# 1098

# %% [markdown]
# ### Save to CSV

# %%
SOD_Morocco.to_csv("results_preprocessed.csv", index = False)
# Choosing to keep the Index for the Answers DataFrame
SOD_Morocco_qst.to_csv("questions_preprocessed.csv", index_label ="Keys" )
